# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset1 = pd.read_csv('test.csv')
dataset2 = pd.read_csv('titanic.csv')
dataset=pd.concat([dataset1,dataset2])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
dataset.shape
# Out:
# (1305, 14)

# %%
dataset.head()
# Out:
#     Age Cabin Embarked     Fare                                          Name  \
# 0  34.5   NaN        Q   7.8292                              Kelly, Mr. James
# 1  47.0   NaN        S   7.0000              Wilkes, Mrs. James (Ellen Needs)
# 2  62.0   NaN        Q   9.6875                     Myles, Mr. Thomas Francis
# 3  27.0   NaN        S   8.6625                              Wirz, Mr. Albert
# 4  22.0   NaN        S  12.2875  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#
#    Parch  Parents/Children Aboard  PassengerId  Pclass     Sex  SibSp  \
# 0    0.0                      NaN        892.0       3    male    0.0
# 1    0.0                      NaN        893.0       3  female    1.0
# 2    0.0                      NaN        894.0       2    male    0.0
# 3    0.0                      NaN        895.0       3    male    0.0
# 4    1.0                      NaN        896.0       3  female    1.0
#
#    Siblings/Spouses Aboard  Survived   Ticket
# ...

# %%
dataset.describe()
# Out:
#                Age         Fare       Parch  Parents/Children Aboard  \
# count  1219.000000  1304.000000  418.000000               887.000000
# mean     29.689639    33.367673    0.392344                 0.383315
# std      14.136760    51.821274    0.981429                 0.807466
# min       0.170000     0.000000    0.000000                 0.000000
# 25%      21.000000     7.895800    0.000000                 0.000000
# 50%      28.000000    14.454200    0.000000                 0.000000
# 75%      38.000000    31.275000    0.000000                 0.000000
# max      80.000000   512.329200    9.000000                 6.000000
#
#        PassengerId       Pclass       SibSp  Siblings/Spouses Aboard  \
# count   418.000000  1305.000000  418.000000               887.000000
# mean   1100.500000     2.292720    0.447368                 0.525366
# std     120.810458     0.838208    0.896760                 1.104669
# ...

# %%
dataset.keys()
# Out:
# Index(['Age', 'Cabin', 'Embarked', 'Fare', 'Name', 'Parch',
#        'Parents/Children Aboard', 'PassengerId', 'Pclass', 'Sex', 'SibSp',
#        'Siblings/Spouses Aboard', 'Survived', 'Ticket'],
#       dtype='object')

# %%
dataset.dropna(subset=['Survived'])
# Out:
#       Age Cabin Embarked      Fare  \
# 0    22.0   NaN      NaN    7.2500
# 1    38.0   NaN      NaN   71.2833
# 2    26.0   NaN      NaN    7.9250
# 3    35.0   NaN      NaN   53.1000
# 4    35.0   NaN      NaN    8.0500
# 5    27.0   NaN      NaN    8.4583
# 6    54.0   NaN      NaN   51.8625
# 7     2.0   NaN      NaN   21.0750
# 8    27.0   NaN      NaN   11.1333
# 9    14.0   NaN      NaN   30.0708
# 10    4.0   NaN      NaN   16.7000
# 11   58.0   NaN      NaN   26.5500
# 12   20.0   NaN      NaN    8.0500
# 13   39.0   NaN      NaN   31.2750
# 14   14.0   NaN      NaN    7.8542
# 15   55.0   NaN      NaN   16.0000
# 16    2.0   NaN      NaN   29.1250
# 17   23.0   NaN      NaN   13.0000
# 18   31.0   NaN      NaN   18.0000
# 19   22.0   NaN      NaN    7.2250
# 20   35.0   NaN      NaN   26.0000
# 21   34.0   NaN      NaN   13.0000
# 22   15.0   NaN      NaN    8.0292
# 23   28.0   NaN      NaN   35.5000
# 24    8.0   NaN      NaN   21.0750
# ...

# %%
dataset.describe()
# Out:
#                Age         Fare       Parch  Parents/Children Aboard  \
# count  1219.000000  1304.000000  418.000000               887.000000
# mean     29.689639    33.367673    0.392344                 0.383315
# std      14.136760    51.821274    0.981429                 0.807466
# min       0.170000     0.000000    0.000000                 0.000000
# 25%      21.000000     7.895800    0.000000                 0.000000
# 50%      28.000000    14.454200    0.000000                 0.000000
# 75%      38.000000    31.275000    0.000000                 0.000000
# max      80.000000   512.329200    9.000000                 6.000000
#
#        PassengerId       Pclass       SibSp  Siblings/Spouses Aboard  \
# count   418.000000  1305.000000  418.000000               887.000000
# mean   1100.500000     2.292720    0.447368                 0.525366
# std     120.810458     0.838208    0.896760                 1.104669
# ...

# %%
dataset['Has_Cabin']=~dataset.Cabin.isnull()

# %%
dataset['Has_Cabin']
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12      True
# 13     False
# 14      True
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24      True
# 25     False
# 26      True
# 27     False
# 28      True
# 29     False
#        ...
# 857    False
# 858    False
# 859    False
# 860    False
# 861    False
# 862    False
# 863    False
# 864    False
# 865    False
# 866    False
# 867    False
# 868    False
# 869    False
# 870    False
# 871    False
# 872    False
# 873    False
# 874    False
# 875    False
# 876    False
# 877    False
# 878    False
# 879    False
# 880    False
# 881    False
# 882    False
# 883    False
# 884    False
# 885    False
# 886    False
# Name: Has_Cabin, Length: 1305, dtype: bool

# %%
import re
list = []
list2=[]
list=dataset['Name']
# Loop starts here
for element in list:
# Out:
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ...

# %%
dataset['Title']=list2

# %%
# Out:
# 0      <_sre.SRE_Match object; span=(0, 2), match='Mr'>
# 1      <_sre.SRE_Match object; span=(0, 2), match='Mr'>
# 2      <_sre.SRE_Match object; span=(0, 2), match='Mr'>
# 3      <_sre.SRE_Match object; span=(0, 2), match='Mr'>
# 4      <_sre.SRE_Match object; span=(0, 2), match='Mr'>
# 5      <_sre.SRE_Match object; span=(0, 2), match='Mr'>
# 6      <_sre.SRE_Match object; span=(0, 2), match='Mr'>
# 7      <_sre.SRE_Match object; span=(0, 2), match='Mr'>
# 8      <_sre.SRE_Match object; span=(0, 2), match='Mr'>
# 9      <_sre.SRE_Match object; span=(0, 2), match='Mr'>
# 10     <_sre.SRE_Match object; span=(0, 2), match='Mr'>
# 11     <_sre.SRE_Match object; span=(0, 2), match='Mr'>
# 12     <_sre.SRE_Match object; span=(0, 2), match='Mr'>
# 13     <_sre.SRE_Match object; span=(0, 2), match='Mr'>
# 14     <_sre.SRE_Match object; span=(0, 2), match='Mr'>
# 15     <_sre.SRE_Match object; span=(0, 2), match='Mr'>
# 16     <_sre.SRE_Match object; span=(0, 2), match='Mr'>
# ...
